# %%
asda_data = "/Users/omkar/Documents/SmartShop/data/All_Data_ASDA.csv"

# %%
import pandas as pd

asda_df = pd.read_csv(asda_data)
asda_df.head()
# Out:
# /var/folders/3q/j28t8qf51r1bnm3d1jkzzmx40000gn/T/ipykernel_11526/3034310473.py:3: DtypeWarning: Columns (0: own_brand) have mixed types. Specify dtype option on import or set low_memory=False.
#   asda_df = pd.read_csv(asda_data)
#   supermarket  prices_(£)  prices_unit_(£) unit  \
# 0        ASDA        4.75             19.8   kg
# 1        ASDA        2.00             26.7   kg
# 2        ASDA        5.00             20.8   kg
# 3        ASDA        3.50             15.4   kg
# 4        ASDA        3.50             15.4   kg
#
#                                                names      date category  \
# 0             Tassimo Cadbury Hot Chocolate Pods x 8  20240413   drinks
# 1     Taylors of Harrogate Hot Lava Java Coffee Bags  20240413   drinks
# 2  Tassimo Limited Edition Cadbury Orange Hot Cho...  20240413   drinks
# 3         ASDA Extra Special Brazilian Ground Coffee  20240413   drinks
# 4           ASDA Extra Special Espresso Coffee Beans  20240413   drinks
#
#   own_brand
# ...

# %%
asda_df['category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
asda_df['date'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 2456414 entries, 0 to 2456413
# Series name: date
# Non-Null Count    Dtype
# --------------    -----
# 2456414 non-null  int64
# dtypes: int64(1)
# memory usage: 18.7 MB

# %%
asda_df['date'] = pd.to_datetime(asda_df['date'], format='%Y%m%d')

# %%
asda_df.head(3)
# Out:
#   supermarket  prices_(£)  prices_unit_(£) unit  \
# 0        ASDA        4.75             19.8   kg
# 1        ASDA        2.00             26.7   kg
# 2        ASDA        5.00             20.8   kg
#
#                                                names       date category  \
# 0             Tassimo Cadbury Hot Chocolate Pods x 8 2024-04-13   drinks
# 1     Taylors of Harrogate Hot Lava Java Coffee Bags 2024-04-13   drinks
# 2  Tassimo Limited Edition Cadbury Orange Hot Cho... 2024-04-13   drinks
#
#   own_brand
# 0     False
# 1     False
# 2     False

# %%
asda_df[asda_df['category'] == 'food_cupboard'].to_csv("/Users/omkar/Documents/SmartShop/data/food_cupboard.csv", index=False)

# %%
asda_df[asda_df['names'].str.contains('coffee', case=False, na=False)]
# Out:
#         supermarket  prices_(£)  prices_unit_(£) unit  \
# 1              ASDA        2.00             26.7   kg
# 3              ASDA        3.50             15.4   kg
# 4              ASDA        3.50             15.4   kg
# 5              ASDA        3.50             15.4   kg
# 6              ASDA        3.50             15.4   kg
# ...             ...         ...              ...  ...
# 2455870        ASDA        6.00             31.6   kg
# 2455872        ASDA       17.00             17.0   kg
# 2455874        ASDA        3.00             15.0   kg
# 2456122        ASDA        3.85             40.5   kg
# 2456123        ASDA        4.00             16.0   kg
#
#                                                      names       date  \
# 1           Taylors of Harrogate Hot Lava Java Coffee Bags 2024-04-13
# 3               ASDA Extra Special Brazilian Ground Coffee 2024-04-13
# 4                 ASDA Extra Special Espresso Coffee Beans 2024-04-13
# ...

# %%
asda_df[asda_df['own_brand'] == False]
# Out:
#         supermarket  prices_(£)  prices_unit_(£)  unit  \
# 0              ASDA        4.75            19.80    kg
# 1              ASDA        2.00            26.70    kg
# 2              ASDA        5.00            20.80    kg
# 9              ASDA        5.90            29.50    kg
# 10             ASDA        5.90            29.50    kg
# ...             ...         ...              ...   ...
# 2456408        ASDA       23.00            23.00  unit
# 2456409        ASDA        8.00             8.00  unit
# 2456410        ASDA        6.00             6.00  unit
# 2456411        ASDA       23.00             0.38     l
# 2456412        ASDA        5.00            28.20     l
#
#                                                      names       date  \
# 0                   Tassimo Cadbury Hot Chocolate Pods x 8 2024-04-13
# 1           Taylors of Harrogate Hot Lava Java Coffee Bags 2024-04-13
# 2        Tassimo Limited Edition Cadbury Orange Hot Cho... 2024-04-13
# ...

# %%
other_brands = asda_df[asda_df['own_brand'] == False]['names']

# %%
for i in other_brands.head():
    print(i.split(" "))
# Out:
# ['Tassimo', 'Cadbury', 'Hot', 'Chocolate', 'Pods', 'x', '8']
# ['Taylors', 'of', 'Harrogate', 'Hot', 'Lava', 'Java', 'Coffee', 'Bags']
# ['Tassimo', 'Limited', 'Edition', 'Cadbury', 'Orange', 'Hot', 'Chocolate', 'Pods', 'x8']
# ['Kenco', 'Decaff', 'Instant', 'Coffee']
# ['Kenco', 'Smooth', 'Instant', 'Coffee']

# %% [markdown]
# #### Loading and Creating a similar subset for sainsburys

# %%
sains_df = pd.read_csv("/Users/omkar/Documents/SmartShop/data/All_Data_Sains.csv")
sains_df.head()
# Out:
#   supermarket  prices_(£)  prices_unit_(£)  unit  \
# 0       Sains        6.00             0.20  unit
# 1       Sains        2.35            11.75    kg
# 2       Sains        2.35            11.75    kg
# 3       Sains        2.15             6.30    kg
# 4       Sains        0.75             7.50    kg
#
#                                                names      date       category  \
# 0  Bassetts Vitamins Omega-3 & Multivits 3-6 Soft...  20240413  baby_products
# 1  Annabel Karmel Chicken & Potato Pie Toddler Me...  20240413  baby_products
# 2  Annabel Karmel Beef Cottage Pie Toddler Meal 2...  20240413  baby_products
# 3               Yeo Valley Organic Little Yeos 4x85g  20240413  baby_products
# 4  The Collective Suckies Strawberry Kids Yoghurt...  20240413  baby_products
#
#    own_brand
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
sains_df['category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
sains_df[sains_df['category'] == 'food_cupboard'].value_counts().plot(kind='bar')

# %%
sains_df[sains_df['category'] == 'food_cupboard'].value_counts().plot(kind='bar')

# %% [markdown]
# ### Extracting BRAND Name

# %%
### Use nlp to extract brand names from the product names and then count the frequency of each brand.

# %% [markdown]
# #### Drop columns and ingest into database. ### MongoDB in the below mentioned format.
# ### Prod ID, Name, Price, Discounted price, Date,
